# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.insert(0, os.path.abspath("..")) #Para poder acceder a src
from src.data_loader import load_imdb_data
from src.data_cleaning import clean_name_basics

# %%
title_basics= load_imdb_data ("title.basics.tsv")
# Out:
# c:\Users\pablo\Desktop\D.A proyectos\iMDB\src\data_loader.py:11: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep=sep)

# %%
title_basics.sample(50)
# Out:
#               tconst     titleType  \
# 2021390   tt11902224     tvEpisode
# 3268652    tt1422536     tvEpisode
# 8421566   tt35050483     tvEpisode
# 1545403   tt11041460     tvEpisode
# 1083395   tt10209766     tvEpisode
# 8679273   tt36151654     tvEpisode
# 5347552   tt21082472     tvEpisode
# 6394440    tt2695346     tvEpisode
# 364909     tt0380944      tvSeries
# 6283618   tt26491511     tvEpisode
# 6374108   tt26896700     tvEpisode
# 10788443   tt7731840     tvEpisode
# 1084336    tt1021142     tvEpisode
# 11590050   tt9482402         movie
# 2011305   tt11884128     tvEpisode
# 6706384   tt28022001     tvEpisode
# 1214994    tt1044752     tvEpisode
# 3198782    tt1409603       tvMovie
# 4880307   tt18766042         short
# 451677     tt0470476         video
# 104993     tt0107433         short
# 6852189   tt28514824     tvEpisode
# 661638     tt0684740     tvEpisode
# 3637282    tt1490414     tvEpisode
# 2951537    tt1364180     tvSpecial
# ...

# %%
def clean_title_basics (df: pd.DataFrame) -> pd.DataFrame:

    for col in ["titleType", "primaryTitle", "originalTitle"]
        if col in df.columns:
            df[col].str.strip()
    
    for col in ["startYear", "endYear", "runtimeMinutes"]
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce").astype("Int64")
            
    return df
